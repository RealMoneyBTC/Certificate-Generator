# %% [markdown]
# # 🧾 Certificate Generator (Plan ₿ Style) - Google Colab
#
# This notebook will:
# - Clone your GitHub repo
# - Install dependencies
# - Prompt for student details
# - Generate a GPG-signed certificate
# - Output a downloadable PDF

# %%
# ✅ Step 1: Clone the repository
# !git clone https://github.com/RealMoneyBTC/Certificate-Generator.git
# %cd Certificate-Generator

# %%
# ✅ Step 2: Install dependencies (LaTeX + Python)
# !apt-get update && apt-get install -y texlive-latex-base texlive-fonts-recommended texlive-latex-extra texlive-xetex lmodern gnupg
# !pip install -r requirements.txt

# %%
# ✅ Step 3: User Input
name = input("Enter student name: ")
course = input("Enter course name: ")
date = input("Enter date (e.g., 2025-07-01): ")

# %%
# ✅ Step 4: Generate certificate
# !python3 generate.py \
  --name "$name" \
  --course "$course" \
  --date "$date" \
  --output "./output/certificate.pdf"

# %%
# ✅ Step 5: Download certificate
from google.colab import files
files.download('./output/certificate.pdf')
